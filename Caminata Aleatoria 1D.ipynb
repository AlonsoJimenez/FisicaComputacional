# %%
# %matplotlib notebook

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import matplotlib.cm as cm

posicionInicial = 0
listaPosiciones = []
listaPosiciones += [posicionInicial]

def updater(deltaT):
    global listaPosiciones
    deltaX = (random.random() - 0.50) * 2
    listaPosiciones += [listaPosiciones[-1] + deltaX]
    xdata.append(deltaT)
    ydata.append(listaPosiciones[-1])
    ln.set_data(xdata, ydata)
    return ln,


fig, ax = plt.subplots()
ax.set_xlim(0, 15)
ax.set_ylim(-4, 4)
#ax.set_ytitle('Distancia (m)')
xdata, ydata = [], []
ln, = plt.plot([], [], 'ro')
ani = FuncAnimation(fig, func = updater, frames=np.arange(0, 15, 1))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
